# %% [markdown]
# ### Required Assignment 5.1: Will the Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaurant near where you are driving. Would you accept that coupon and take a short detour to the restaurant? Would you accept the coupon but use it on a subsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaurant? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\$20 - $50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
#data.describe()
print("Missing values in the dataset:")
print(data.isnull().sum())

print("\nPercentage missing:")
print((data.isnull().sum() / len(data)) * 100)
# Out:
# Missing values in the dataset:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64
#
# Percentage missing:
# destination              0.000000
# passanger                0.000000
# ...

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
## car coulmn has 99% missing values, so we will drop it
data = data.drop(columns=['car'], axis=1, errors='ignore')

## fill the missing values with 'never'
cols_to_fill = ['Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50']
data[cols_to_fill] = data[cols_to_fill].fillna('never')

#data.isnull().sum()
## replace the values with numeric values
# Set option to avoid FutureWarning about downcasting
pd.set_option('future.no_silent_downcasting', True)
data = data.replace({'never': 0,'less1': 0,'1~3': 2,'4~8': 6,'gt8': 8}).infer_objects(copy=False)

## replace the age values with numeric values
data['age'] = data['age'].replace({'below21': 20,'50plus': 50})
data['age'] = pd.to_numeric(data['age'])

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
total_accespted =data['Y'].value_counts() / len(data)

print(f"{total_accespted[1]*100:.2f} of the total observations chose to accept the coupon.")

accept_counts = data['Y'].value_counts().sort_index()
plt.figure(figsize=(6, 4))
sns.barplot(x=accept_counts.index.map({0: "No", 1: "Yes"}), y=accept_counts.values)
plt.title('Accepted vs Unaccepted Coupons')
plt.xlabel('Accepted Coupon')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('images/accepted_vs_unaccepted.png')
plt.show()
# Out:
# 56.84 of the total observations chose to accept the coupon.

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='coupon', y='Y', data=data)
plt.title('Coupon Acceptance Rate by Type')
plt.xlabel('Coupon Type')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('images/coupon_acceptance_rate.png')
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.histplot(data, x='temperature', hue='Y')

plt.savefig('images/temperature_histogram.png')
plt.show()

# %%
sns.boxplot(data['temperature'])

plt.savefig('images/temperature_boxplot.png')

plt.show()

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons = data[data['coupon'] == 'Bar'].dropna()
#bar_coupons.isnull().sum()

#bar_coupons = bar_coupons.dropna()

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
accepted = bar_coupons['Y'].value_counts() / len(bar_coupons)
print(f"{accepted[1]*100:.2f} of bar coupons were accepted.")

accept_counts = bar_coupons['Y'].value_counts(normalize=True).sort_index() * 100
labels = ['Unused', 'Accepted']  

plt.figure(figsize=(6,4))
sns.barplot(x=labels, y=accept_counts.values)
plt.title('Accepted vs Unused Bar Coupons (Percentage)')
plt.ylabel('Percentage of Coupons (%)')
plt.xlabel('Coupon Status')
plt.ylim(0, 100)

plt.savefig('images/bar_acceptance_rate_percentage.png')
plt.show()
# Out:
# 41.00 of bar coupons were accepted.

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
bar_3_or_fewer = bar_coupons[bar_coupons['Bar'].isin([0, 2])]

acceptance_rate_3_or_fewer = bar_3_or_fewer['Y'].sum() / len(bar_3_or_fewer)
print(f"Acceptance rate (3 or fewer): {acceptance_rate_3_or_fewer:.2%}")

bar_more_than_3 = bar_coupons[bar_coupons['Bar'].isin([6, 8])]
acceptance_rate_more_than_3 = bar_more_than_3['Y'].sum() / len(bar_more_than_3)
print(f"Acceptance rate (more than 3): {acceptance_rate_more_than_3:.2%}")

plt.figure(figsize=(8, 5))
plt.bar(['3 or fewer', 'more than 3'], [acceptance_rate_3_or_fewer, acceptance_rate_more_than_3])
plt.title('Bar Coupon Acceptance Rate: 3 or Fewer vs More Than 3 Visits/Month')
plt.xlabel('Bar Visit Frequency')
plt.ylabel('Acceptance Rate')
plt.ylim(0, 1)
plt.tight_layout()
plt.savefig('images/bar_acceptance_rate.png')
plt.show()
# Out:
# Acceptance rate (3 or fewer): 37.07%
# Acceptance rate (more than 3): 76.88%

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
group1 = bar_coupons[
    (bar_coupons['Bar'] > 0) & 
    (bar_coupons['age'] > 25)
]

# All other drivers
group2 = bar_coupons[
    ~((bar_coupons['Bar'] > 0) & 
      (bar_coupons['age'] > 25))
]

acceptance_rate_group1 = group1['Y'].sum() / len(group1)
acceptance_rate_group2 = group2['Y'].sum() / len(group2)

print(f"  Acceptance rate for drivers going to bar more than once a month and above age of 25: {acceptance_rate_group1:.2%}")
print(f"  Acceptance rate for other drivers: {acceptance_rate_group2:.2%}")
print(f"\nDifference: {acceptance_rate_group1 - acceptance_rate_group2:.2%}")
print(f"Is there a difference? {'YES' if acceptance_rate_group1 > acceptance_rate_group2 else 'NO'}")
# Out:
#   Acceptance rate for drivers going to bar more than once a month and above age of 25: 69.52%
#   Acceptance rate for other drivers: 33.50%
#
# Difference: 36.02%
# Is there a difference? YES

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
group1_q5 = bar_coupons[
    (bar_coupons['Bar'] > 0) & 
    (bar_coupons['passanger'] != 'Kid(s)') &
    (bar_coupons['occupation'] != 'Farming Fishing & Forestry')
]

# All other drivers
group2_q5 = bar_coupons[
    ~((bar_coupons['Bar'] > 0) & 
      (bar_coupons['passanger'] != 'Kid(s)') &
      (bar_coupons['occupation'] != 'Farming Fishing & Forestry'))
]

acceptance_rate_group_bar_more_than_once_a_month_and_not_a_kid_and_not_farming = group1_q5['Y'].sum() / len(group1_q5)
acceptance_rate_other_drivers = group2_q5['Y'].sum() / len(group2_q5)

print(f"  Acceptance rate for drivers going to bar more than once/month, no kids, not farming: {acceptance_rate_group_bar_more_than_once_a_month_and_not_a_kid_and_not_farming:.2%}")
print(f"  Acceptance rate for other drivers: {acceptance_rate_other_drivers:.2%}")
print(f"\nDifference: {acceptance_rate_group_bar_more_than_once_a_month_and_not_a_kid_and_not_farming - acceptance_rate_other_drivers:.2%}")
print(f"Is there a difference? {'YES' if acceptance_rate_group_bar_more_than_once_a_month_and_not_a_kid_and_not_farming > acceptance_rate_other_drivers else 'NO'}")
# Out:
#   Acceptance rate for drivers going to bar more than once/month, no kids, not farming: 71.32%
#   Acceptance rate for other drivers: 29.60%
#
# Difference: 41.72%
# Is there a difference? YES

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
# Condition 1: Go to bars more than once a month, no kids, not widowed
condition1 = (
    (bar_coupons['Bar'] > 0) & 
    (bar_coupons['passanger'] != 'Kid(s)') &
    (bar_coupons['maritalStatus'] != 'Widowed')
)

# Condition 2: Go to bars more than once a month and under age 30
condition2 = (
    (bar_coupons['Bar'] > 0) & 
    (bar_coupons['age'] < 30)
)

# Condition 3: Go to cheap restaurants more than 4 times a month and income < $50K
condition3 = (
    (bar_coupons['RestaurantLessThan20'] >= 6) & 
    (bar_coupons['income'].isin(['Less than $12500', '$12500 - $24999', '$25000 - $37499', '$37500 - $49999']))
)

group_meeting_conditions = bar_coupons[condition1 | condition2 | condition3]
group_other_drivers = bar_coupons[~(condition1 | condition2 | condition3)]

acceptance_rate_meeting_conditions = group_meeting_conditions['Y'].sum() / len(group_meeting_conditions)
acceptance_rate_other_drivers = group_other_drivers['Y'].sum() / len(group_other_drivers)

print(f"  Acceptance rate for drivers meeting any condition: {acceptance_rate_meeting_conditions:.2%}")
print(f"  Acceptance rate for other drivers: {acceptance_rate_other_drivers:.2%}")
print(f"\nDifference: {acceptance_rate_meeting_conditions - acceptance_rate_other_drivers:.2%}")
print(f"Is there a difference? {'YES' if acceptance_rate_meeting_conditions > acceptance_rate_other_drivers else 'NO'}")
# Out:
#   Acceptance rate for drivers meeting any condition: 58.89%
#   Acceptance rate for other drivers: 29.81%
#
# Difference: 29.08%
# Is there a difference? YES

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# Overall coupon acceptance across all categories was at ~56% whereas Bar coupon acceptance rate was at ~41%, here are some notable insight driven from data.
# 1. people who are going to bar are more likely accept the coupons.
# 2. drivers going bar more than 1 times in a month and above age of 25 has high rate of acceptance rate.
# 3. cost consious driver are more likely to accept coupons.
# 4. drivers having non-farming occupations are are most likely accept the coupons.
# 5. driver who never go to bars are least likely accept the coupons.

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
**Note for Future Investigations:**

Please ensure that you create a GUS (General Understanding Structure) using the established structure template when conducting future investigations. This will help maintain consistency and thoroughness in your analytical approach.

**Investigation Structure Template:**
1. **Data Exploration** - Initial examination of the dataset
2. **Hypothesis Formation** - Clear statement of what you expect to find
3. **Analysis Methodology** - Detailed approach and techniques used
4. **Results & Findings** - Key insights and patterns discovered
5. **Conclusions & Recommendations** - Actionable insights based on the analysis
# Out:
#   Cell In[35], line 1
#     **Note for Future Investigations:**
#     ^
# SyntaxError: invalid syntax

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  int64
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  Bar                   12684 non-null  int64
# ...

# %%
coupon_type = data['coupon'].value_counts().reset_index()
used_coupons = data[data['Y'] == 1]
used_coupon_type = used_coupons['coupon'].value_counts().reset_index().sort_index(ascending = True)


plt.figure(figsize=(8, 5))
sns.countplot(x='coupon', data=data)
plt.title('Count of Each Coupon Type')
plt.xlabel('Coupon Type')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.tight_layout()

plt.savefig('images/coupon_type_count.png')
plt.show()

# %%
#find out the acceptance rate of coupon by occupation
coupon_acceptance_rate = data.groupby('occupation')['Y'].mean()
print(coupon_acceptance_rate)
plt.figure(figsize=(12,6))
coupon_acceptance_rate.plot(kind='bar', color='skyblue')
plt.title('Coupon Acceptance Rate by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('images/coupon_acceptance_rate_by_occupation.png')
plt.show()

#find out the acceptance rate of coupon by age
coupon_acceptance_rate = data.groupby('age')['Y'].mean()
print(coupon_acceptance_rate)
plt.figure(figsize=(12,6))
coupon_acceptance_rate.plot(kind='bar', color='salmon')
plt.title('Coupon Acceptance Rate by Age')
plt.xlabel('Age')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('images/coupon_acceptance_rate_by_age.png')
plt.show()
# Out:
# occupation
# Architecture & Engineering                   0.634286
# Arts Design Entertainment Sports & Media     0.518283
# Building & Grounds Cleaning & Maintenance    0.590909
# Business & Financial                         0.569853
# Community & Social Services                  0.489627
# Computer & Mathematical                      0.566761
# Construction & Extraction                    0.688312
# Education&Training&Library                   0.523860
# Farming Fishing & Forestry                   0.534884
# Food Preparation & Serving Related           0.583893
# Healthcare Practitioners & Technical         0.676230
# Healthcare Support                           0.698347
# Installation Maintenance & Repair            0.533835
# Legal                                        0.470320
# Life Physical Social Science                 0.576471
# Management                                   0.588305
# Office & Administrative Support              0.600939
# ...

# %%
# Plot heatmap of correlation between acceptance rate and other variables
numeric_data = data.select_dtypes(include=[np.number])
correlation_matrix = numeric_data.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
plt.title('Correlation Matrix between Acceptance Rate and Other Numeric Variables')
plt.tight_layout()
plt.savefig('images/correlation_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Findings and Conclusions
#
#
# - Overall coupon acceptance rate: **56.84%**
# - Bar coupons had lower acceptance: **41.00%**
#
# **Bar Coupon Analysis**
#    - Visit Frequency Matters Most
#    - Drivers visiting bars 3 or fewer times/month: 37.07% acceptance
#    - Drivers visiting bars more than 3 times/month: **76.88% acceptance** (2x higher)
#    - Bar-goers (>1/month) over age 25: **69.52% acceptance**, All others: 33.50% acceptance,  Difference: 36.02 percentage points
#    - Bar-goers (>1/month), no kids, non-farming occupation: **71.32% acceptance** while All others: 29.60% acceptance, Having kids as passengers drastically reduces bar coupon acceptance
#    - Drivers meeting favorable conditions (frequent bar/restaurant visits, younger age, no kids): **58.89% acceptance** while Drivers not meeting these conditions: 29.81% acceptance
#    - Younger drivers (age 20) highest acceptance (63.44%), decreases with age
#    - Occupation Healthcare Support (69.83%) and Construction (68.83%) highest; Retired (45.86%) and Legal (47.03%) lowest
#
#
# ### Conclusions
#
#  - Drivers who regularly visit a venue type are 2x more likely to accept related coupons
#  - Passenger type (especially having children) significantly impacts acceptance, particularly for bar coupons
#  - Acceptance rates decline with age, with under-30 drivers showing highest engagement
